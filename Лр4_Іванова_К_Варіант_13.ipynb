# %% [markdown]
# <a href="https://colab.research.google.com/github/vos32/Github/blob/main/%D0%9B%D1%804_%D0%86%D0%B2%D0%B0%D0%BD%D0%BE%D0%B2%D0%B0_%D0%9A_%D0%92%D0%B0%D1%80%D1%96%D0%B0%D0%BD%D1%82_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Іванова Карина. Варіант 13

# %%
import numpy as np
numpy_version = np.__version__
numpy_version
# Out:
# '2.0.2'

# %% [markdown]
# 1.

# %%
matrix = np.random.randint(1, 6, size=(3,3))
matrix
# Out:
# array([[1, 5, 1],
#        [2, 5, 2],
#        [1, 3, 3]])

# %% [markdown]
# 2.

# %%
det = np.linalg.det(matrix)
det
# Out:
# np.float64(-10.000000000000002)

# %% [markdown]
# 3.

# %%
product = np.prod(matrix)
product
# Out:
# np.int64(900)

# %%
prod_1 = np.prod(matrix[0])
prod_2 = np.prod(matrix[1])
prod_3 = np.prod(matrix[2])
prod_1*prod_2*prod_3
# Out:
# np.int64(900)

# %% [markdown]
# 4.

# %%
np.sum(matrix)
# Out:
# np.int64(23)

# %% [markdown]
# 5.

# %%
np.max(matrix)
# Out:
# np.int64(5)

# %%
np.min(matrix)
# Out:
# np.int64(1)

# %% [markdown]
# 6.

# %%
np.mean(matrix)
# Out:
# np.float64(2.5555555555555554)

# %% [markdown]
# 7.

# %%
sqrt_matrix= np.sqrt(matrix)

print(sqrt_matrix)
# Out:
# [[1.         2.23606798 1.        ]
#  [1.41421356 2.23606798 1.41421356]
#  [1.         1.73205081 1.73205081]]

# %% [markdown]
# 8.

# %%
np.sum(matrix, axis=1).reshape(-1,1)
# Out:
# array([[7],
#        [9],
#        [7]])

# %%
np.sum(matrix, axis=1)
# Out:
# array([7, 9, 7])

# %%
x = np.matrix([[1,2], [4,3]])
x
# Out:
# matrix([[1, 2],
#         [4, 3]])

# %%
x.sum(axis=1)
# Out:
# matrix([[3],
#         [7]])

# %% [markdown]
# 9. Створити вектор, що містить 25 елементів. Заповнити числами від 0 до 9. Відсортувати числа за спаданням.

# %%
vector = np.random.randint(0, 10, size=25)
vector
# Out:
# array([8, 3, 5, 4, 3, 6, 2, 2, 5, 3, 9, 7, 4, 3, 8, 6, 9, 2, 9, 9, 1, 0,
#        2, 7, 4])

# %%
#Сортуємо числа за спаданням
sorted_vector = np.sort(vector)[::-1]
sorted_vector
# Out:
# array([9, 9, 9, 9, 8, 8, 7, 7, 6, 6, 5, 5, 4, 4, 4, 3, 3, 3, 3, 2, 2, 2,
#        2, 1, 0])

# %% [markdown]
# 10.Знайти моду, медіану, середнє, максимальне, мінімальне значення

# %%
from scipy import stats

# %%
stats.mode(vector)
# Out:
# ModeResult(mode=np.int64(2), count=np.int64(4))

# %%
np.median(vector)
# Out:
# np.float64(4.0)

# %%
np.max(vector)
# Out:
# np.int64(9)

# %%
np.min(vector)
# Out:
# np.int64(0)

# %% [markdown]
# Лр4 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
a = np.array([
    [1, -4, 0],
    [2, -3, 1],
    [1, 4, 2],
])
b = np.array([[-5], [-7], [-1]])

# %%
#Матричний метод (1 спосіб)
det_a = np.linalg.det(a)
if det_a == 0:
    print("Визначник дорівнює нулю - рішень немає")
else:
  a_inv = np.linalg.inv(a)
  print(f"Обернена матриця до матриці A: \r\n {a_inv }")
  print(f"Вектор рішення: \r\n {a_inv.dot(b)}")
# Out:
# Обернена матриця до матриці A:
#  [[-5.   4.  -2. ]
#  [-1.5  1.  -0.5]
#  [ 5.5 -4.   2.5]]
# Вектор рішення:
#  [[-1.]
#  [ 1.]
#  [-2.]]

# %%
# Напиши функцію для вирішення системи матричним методом (2 спосіб)
def solve_inv_matrix(a, b, verbose=False):
    det = np.linalg.det(a)
    if verbose: print(f"Визначник матриці A: {round(det)}")
    if det == 0:
        print("Визначник дорівнює нулю - рішень немає")
        return None

    a_inv= np.linalg.inv(a)
    if verbose: print(f"Обернена матриця до матриці A: \r\n {a_inv }")
    return a_inv.dot(b)

print(f"Вектор рішення: \r\n {solve_inv_matrix(a, b)}")
# Out:
# Вектор рішення:
#  [[-1.]
#  [ 1.]
#  [-2.]]

# %%
#метод Крамера (1 спосіб)
# Метод Крамера
det_a = np.linalg.det(a)

if det_a == 0:
    print("Визначник дорівнює нулю — система не має єдиного розв’язку.")
else:
    def replace_column(matrix, column_index, new_column):
        new_matrix = np.copy(matrix)
        new_matrix[:, column_index] = new_column
        return new_matrix

    # Обчислюємо Δx, Δy, Δz
    delta_x = np.linalg.det(replace_column(a, 0, b.T))
    delta_y = np.linalg.det(replace_column(a, 1, b.T))
    delta_z = np.linalg.det(replace_column(a, 2, b.T))

    # Обчислюємо x, y, z
    print('x =', delta_x / det_a)
    print('y =', delta_y / det_a)
    print('z =', delta_z / det_a)
# Out:
# x = -1.0000000000000053
# y = 1.0
# z = -1.9999999999999978

# %%
# Напиши функцію для вирішення системи методом Крамера
def solve_cramer(a, b, verbose=False):
    det = np.linalg.det(a)
    if verbose: print(f"Визначник матриці A: {round(det)}")
    if det == 0:
        print("Визначник дорівнює нулю - рішень немає")
        return None

    len_a = len(a)
    x = np.zeros((len_a, 1))
    for i in range(len_a):
        temp = np.copy(a)
        temp[:, [i]] = b
        x[i, 0] = np.linalg.det(temp)/det

    return x


print(f"Вектор рішення: \r\n {solve_cramer(a, b)}")
# Out:
# Вектор рішення:
#  [[-1.]
#  [ 1.]
#  [-2.]]

# %%
x = np.linalg.solve(a, b)

print(x)
# Out:
# [[-1.]
#  [ 1.]
#  [-2.]]
